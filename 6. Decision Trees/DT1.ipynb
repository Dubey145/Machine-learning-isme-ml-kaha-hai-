# %% [markdown]
# <h2>Decision Tree</h2>
# - another classification algorithm <br>
# - it is a step by step decision making algorithm that eventually makes a decision by taking us to a leaf <br>
# - at every leaf there is an output<br>
# - at every non leaf node there is a decision being made

# %% [markdown]
# ![Screenshot%202022-05-07%20at%204.58.16%20AM.png](attachment:Screenshot%202022-05-07%20at%204.58.16%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-07%20at%205.00.09%20AM.png](attachment:Screenshot%202022-05-07%20at%205.00.09%20AM.png)

# %% [markdown]
# Getting to the most accurate DT in a definite amount of time is computationally impossible <br>
# time complexity of suck an algo is exponential <br>
# **It is an NP hard problem** <br>
# <pre>
# we will use greedy approach
# but
# decide on which feature to split on
#
# in the greedy approach we will not worry about what will happen later to the
# accuracy
# instead we will just be greedy and think about the feature to split on for each
# step
#
# for features say x1,x2,x3,x4
# we will ask
# "if i split on x1 what is the gain?"
# "if i split on x2 what is the gain?"
# and then decide accordingly
#
# the gain or metric can be accuracy or anything
#
# </pre>

# %% [markdown]
# 1. if the node is pure : points of only one class - then dont split further just output the class
# 2. if no feature is left to split upon output majority
# 3. otherwise find the best feature to split upon
# 4. recursively call on the splits

# %% [markdown]
# # Different Objective Metrics
#
# ![Screenshot%202022-05-07%20at%206.18.04%20AM.png](attachment:Screenshot%202022-05-07%20at%206.18.04%20AM.png)

# %% [markdown]
# # accuracy for splitting based on
# 1. college tier
# 2. internship
# <br>only one stage of splitting and the output is based on majority
# so while calculating accuracy we add majority and / by total data points

# %% [markdown]
# ![Screenshot%202022-05-07%20at%206.29.20%20AM.png](attachment:Screenshot%202022-05-07%20at%206.29.20%20AM.png)

# %% [markdown]
# <h3>on the same level splitting can be done based on different classes</h3>
#
# ![Screenshot%202022-05-07%20at%206.35.18%20AM.png](attachment:Screenshot%202022-05-07%20at%206.35.18%20AM.png)

# %% [markdown]
# for the above examples we had data already classified into groups i.e Tier 1,2,3
# - what if the data is not grouped?
# - what if it is in continuous values ?

# %% [markdown]
# for continuous data put a boundary
#
# ![Screenshot%202022-05-07%20at%206.43.09%20AM.png](attachment:Screenshot%202022-05-07%20at%206.43.09%20AM.png)

# %% [markdown]
# we can do the following
# 1. sort the data put it on a number line and select the midpoint as the splitter
# 2. on the numberline select the midpoint of 2 values and split according to that value
# then select the next 2 values and split according to their midpoint and so on
# <br>
# the 2nd method is kind of a brute force where the accuracy is checked for each midpoint
#
# ![Screenshot%202022-05-07%20at%206.52.53%20AM.png](attachment:Screenshot%202022-05-07%20at%206.52.53%20AM.png)
