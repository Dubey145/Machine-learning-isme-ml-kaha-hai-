# %% [markdown]
# # INFORMATION GAIN

# %% [markdown]
# ![Screenshot%202022-05-19%20at%203.48.07%20AM.png](attachment:Screenshot%202022-05-19%20at%203.48.07%20AM.png)

# %% [markdown]
# if a class was pure then the first term 9/29 will not be there and the entropy will be 0
# - entropy ranges form 0 to 1
# - 1 means that is is a completely impure subset

# %% [markdown]
# we have to split in a way that leads to the maximum decrease in entropy

# %% [markdown]
# ![Screenshot%202022-05-19%20at%204.06.21%20AM.png](attachment:Screenshot%202022-05-19%20at%204.06.21%20AM.png)

# %% [markdown]
# H(S) is the entropy of the split, same formula as INFOn
# Sv = sample after the split
# - entropy is used to calculate the infromation gain
# - higher the information gain better the split
