# %% [markdown]
# # Pruning
# ![Screenshot%202022-05-19%20at%207.02.32%20PM.png](attachment:Screenshot%202022-05-19%20at%207.02.32%20PM.png)

# %% [markdown]
# when the complexity of the tree increases the error on the training data decreases
# - overfitting takers place <br>
# but as complexity increases the error with testing data increases

# %% [markdown]
# <h3>lesser the leaf nodes lesser the complexity</h3>

# %% [markdown]
# lets create a cost function that would minimize errors and leafs
#
# cost = error + (lambda)*leaf

# %% [markdown]
# sample tree :
# ![Screenshot%202022-05-19%20at%207.20.59%20PM.png](attachment:Screenshot%202022-05-19%20at%207.20.59%20PM.png)

# %% [markdown]
# cost = 0 + 10(leaves)

# %% [markdown]
# <pre>
# if we get rid of the split 1y 2n
# the cost becomes cost = 1+9
# error becomnes one because the majority becomes 2 and it will be predicted as no
# so that 1y will also be N
# </pre>
