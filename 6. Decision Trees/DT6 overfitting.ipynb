# %% [markdown]
# in DT, overfitting is a very common problem

# %% [markdown]
# DT will keep splitting until pure nodes are obtained which will lead to 0 training errors

# %% [markdown]
# to avoid that we have to add more criterias to stop splitting, to not build the whole tree and stop early

# %% [markdown]
# or build the whole tree and perfrm pruning
# figure out which splits were not useful and remove them

# %% [markdown]
# # To End Early

# %% [markdown]
# 1. define max depth - problem - how to get that optimal depth?
# 2. Cant define on which side to split more and on which to stop
# 3. Forces balance on both sides
# 4. we can decide to stop when the is no significant improvement on a score
# 5. but sometimes a score will be the same and it would be better to split
#
# 6. due to these limitations we do not stop early instead we perform pruning

# %% [markdown]
# ![Screenshot%202022-05-19%20at%205.51.14%20AM.png](attachment:Screenshot%202022-05-19%20at%205.51.14%20AM.png)
