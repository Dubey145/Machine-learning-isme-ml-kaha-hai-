# %% [markdown]
# # Gain Ratio

# %% [markdown]
# gain ration is a way to penalize the algo if it splits a class into a lot of small nodes

# %% [markdown]
# ![Screenshot%202022-05-19%20at%204.24.00%20AM.png](attachment:Screenshot%202022-05-19%20at%204.24.00%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-19%20at%204.24.59%20AM.png](attachment:Screenshot%202022-05-19%20at%204.24.59%20AM.png)

# %% [markdown]
# D is the size of that particulat split
# ![Screenshot%202022-05-19%20at%204.27.14%20AM.png](attachment:Screenshot%202022-05-19%20at%204.27.14%20AM.png)

# %% [markdown]
# - gain ration will try to have smaller pure classes
# - even if it is an unbalanced split

# %% [markdown]
# gain ratio = info gain / split info
