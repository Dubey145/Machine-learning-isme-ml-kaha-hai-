# %% [markdown]
# # Gini Index

# %% [markdown]
# gini index leads to binary splits
# ![Screenshot%202022-05-19%20at%205.02.44%20AM.png](attachment:Screenshot%202022-05-19%20at%205.02.44%20AM.png)

# %% [markdown]
#  the gini index of the split will be the weighted average of d1 and d2 (classes splitted upon)
# ![Screenshot%202022-05-19%20at%205.07.58%20AM.png](attachment:Screenshot%202022-05-19%20at%205.07.58%20AM.png)

# %% [markdown]
# lower gini index is better
# the change in gini is calculated for each feature and then this is performed
# ![Screenshot%202022-05-19%20at%205.11.30%20AM.png](attachment:Screenshot%202022-05-19%20at%205.11.30%20AM.png)

# %% [markdown]
#  whichever feature gives the maximum difference that split is taken
