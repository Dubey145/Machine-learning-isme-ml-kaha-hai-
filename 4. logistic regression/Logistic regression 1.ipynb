# %% [markdown]
# # LOGISTIC REGRESSION

# %% [markdown]
# logistics regression is used as a classification algorithm
# in binary classification they y values will be either 0 or 1

# %% [markdown]
# - if we use linear regression for classification the algorithm would find the best fit line, something like the images below

# %% [markdown]
# ![Screenshot%202022-05-04%20at%204.55.52%20AM.png](attachment:Screenshot%202022-05-04%20at%204.55.52%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-04%20at%204.58.08%20AM.png](attachment:Screenshot%202022-05-04%20at%204.58.08%20AM.png)

# %% [markdown]
# a simple method that we can follow would be after the algo predicts a line
# and if new input x has y>0.5 it will be 1 else 0
#
# - but the problem with this method isthat if we add more data points then our plotted line changes and with that the x that was predicting 1 earlier might not predict 1 anymore
# as the threshold x has increased

# %% [markdown]
# ![Screenshot%202022-05-04%20at%205.02.01%20AM.png](attachment:Screenshot%202022-05-04%20at%205.02.01%20AM.png)

# %% [markdown]
# having a couple of outliers, extreme values will ruin the LINEAR reression algorithm

# %% [markdown]
# # Decision Boundary
# there will be one cut on the x axis and anything below that x will be 0 and anything above that will be 1

# %% [markdown]
# ![Screenshot%202022-05-04%20at%205.11.40%20AM.png](attachment:Screenshot%202022-05-04%20at%205.11.40%20AM.png)

# %% [markdown]
# some other types of decision boundary
# ![Screenshot%202022-05-04%20at%205.22.31%20AM.png](attachment:Screenshot%202022-05-04%20at%205.22.31%20AM.png)

# %% [markdown]
# \+ = y for 0
# x = y for 1

# %% [markdown]
# non linear decision boundary
#
# ![Screenshot%202022-05-04%20at%205.25.15%20AM.png](attachment:Screenshot%202022-05-04%20at%205.25.15%20AM.png)
