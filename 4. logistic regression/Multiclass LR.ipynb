# %% [markdown]
# Multiclass logistic Regression follows a 1vs rest approach
# - we build 3 models
# ![Screenshot%202022-05-04%20at%207.45.00%20AM.png](attachment:Screenshot%202022-05-04%20at%207.45.00%20AM.png)

# %% [markdown]
# 3 separate models trained separately each model will give y = something between 0-1 that can be used as probability
#
# - mdoel 1 will tell Probability of a cat
# - model 2 - rat
# - model 3 - dog
# <br>
# we then select the output with the highest probability to classify

# %% [markdown]
# 2nd complex method
# # Multinomial logistic regression
#
# - lets train only one model which has more parameters
# - say "k" classes
# - the model calculates the probability of each class and the one with the max prob. is selected
# - in sklearn we can decide if we want to use 1vs rest or multinomial
# ![Screenshot%202022-05-04%20at%207.55.26%20AM.png](attachment:Screenshot%202022-05-04%20at%207.55.26%20AM.png)

# %% [markdown]
# <h3>Finding complex boundaries and regularization</h3>
# <pre>
# while calculating boundaries if we add more parameters eg squard value
# we might end up overfitting the data
# to avoid that
# the process of regularization is used which basically adds an additional cost
# to the existing cost function
# this would solve the overfitting problem
#
# when we sum the square the parameters it is called l2 vectorization
# when we add the mod of parameters it is called l1 vectorization
#
# regularization is not done on the intercept
#
# </pre>
