# %% [markdown]
# the problems with linear regression being used for classification were
# - incorrect decision boundary
# - values not between 0 and 1

# %% [markdown]
# with logistic regression we want our values to be between 0 and 1

# %% [markdown]
# **Sigmoid function**

# %% [markdown]
# ![Screenshot%202022-05-04%20at%205.43.51%20AM.png](attachment:Screenshot%202022-05-04%20at%205.43.51%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-04%20at%205.46.59%20AM.png](attachment:Screenshot%202022-05-04%20at%205.46.59%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-04%20at%205.48.06%20AM.png](attachment:Screenshot%202022-05-04%20at%205.48.06%20AM.png)

# %% [markdown]
# when z = 0 s = 0.5, the y intercept is 0.5

# %% [markdown]
# Logistic regression math![Screenshot%202022-05-04%20at%205.51.56%20AM.png](attachment:Screenshot%202022-05-04%20at%205.51.56%20AM.png)

# %% [markdown]
# # cost function

# %% [markdown]
# we cant use gradient descent to minimise the cost function as there will me multiple minimas
# as in multiple local minimas
# here H(x) is more complex
# ![Screenshot%202022-05-04%20at%206.17.41%20AM.png](attachment:Screenshot%202022-05-04%20at%206.17.41%20AM.png)

# %% [markdown]
# the error function that we will use is
# ![Screenshot%202022-05-04%20at%206.20.03%20AM.png](attachment:Screenshot%202022-05-04%20at%206.20.03%20AM.png)

# %% [markdown]
# as h(x) goes to 0 error goes to inf
# as h(x) goes to 1 error goes to 1
# ![Screenshot%202022-05-04%20at%206.23.22%20AM.png](attachment:Screenshot%202022-05-04%20at%206.23.22%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-04%20at%206.26.41%20AM.png](attachment:Screenshot%202022-05-04%20at%206.26.41%20AM.png)

# %% [markdown]
# # Finding optimal values
# error function is
# ![Screenshot%202022-05-04%20at%206.40.11%20AM.png](attachment:Screenshot%202022-05-04%20at%206.40.11%20AM.png)

# %% [markdown]
# - we have to find the optimal m value
# - we will use gradient descent
